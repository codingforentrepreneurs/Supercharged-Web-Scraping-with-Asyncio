# %%
from supercharged.storage import df_from_sql

# %%
tables = [
    'spoonflower_links',
    'spoonflower_fabrics'
]

# %%
links_df = df_from_sql(tables[0])
products_df = df_from_sql(tables[1])

# %%
links_df.head()
# Out:
#         id                                               slug  \
# 0  7522587      save-honey-bees-large-new-by-fernlesliestudio
# 1  1306112                         opal-by-peacoquettedesigns
# 2  9060289  saints-fleur-de-lis-new-orleans-saints-footbal...
# 3  5773745                  rainbow-pride-stripes-by-furbuddy
# 4  7812388                        dnd-pattern-by-neonborealis
#
#                                                 path  scraped
# 0  /en/fabric/7522587-save-honey-bees-large-new-b...        0
# 1      /en/fabric/1306112-opal-by-peacoquettedesigns        1
# 2  /en/fabric/9060289-saints-fleur-de-lis-new-orl...        0
# 3  /en/fabric/5773745-rainbow-pride-stripes-by-fu...        0
# 4     /en/fabric/7812388-dnd-pattern-by-neonborealis        0

# %%
links_df.shape
# Out:
# (3856, 4)

# %%
products_df.head(n=100)
# Out:
#          id                                               slug  \
# 0   6444170                catching-fireflies-by-thestorysmith
# 1   3584004            mexican-sugar-skulls-small-by-lusykoror
# 2   7984669              8-love-care-medical-white-by-rebelmod
# 3   8619105               flight-feathers-painted-by-xoxotique
# 4   7944022  golden-girls-illustration-peach-by-yesterdayco...
# ..      ...                                                ...
# 95  6947878  gold-lips-on-graphite-grey-gray-gold-kiss-by-m...
# 96  5872295  fall-plaid-navy-rustic-woods-blue-white-by-lit...
# 97  7582998  leopard-rose-gold-spots-on-pink-by-paper_and_f...
# 98  5566933  galaxy-far-far-away-1in-chibi-gray-by-studiofi...
# 99  6735421                 jurassic-halloween-by-penguinhouse
#
#                                                  path  \
# 0   /en/fabric/6444170-catching-fireflies-by-thest...
# 1   /en/fabric/3584004-mexican-sugar-skulls-small-...
# 2   /en/fabric/7984669-8-love-care-medical-white-b...
# 3   /en/fabric/8619105-flight-feathers-painted-by-...
# 4   /en/fabric/7944022-golden-girls-illustration-p...
# ..                                                ...
# 95  /en/fabric/6947878-gold-lips-on-graphite-grey-...
# 96  /en/fabric/5872295-fall-plaid-navy-rustic-wood...
# 97  /en/fabric/7582998-leopard-rose-gold-spots-on-...
# 98  /en/fabric/5566933-galaxy-far-far-away-1in-chi...
# 99  /en/fabric/6735421-jurassic-halloween-by-pengu...
#
#                                             title                   size  \
# 0                              Catching Fireflies  Fat Quarter 21" x 18"
# 1                    Mexican Sugar Skulls (small)  Fat Quarter 21" x 18"
# 2                 8" Love to Care Medical - White  Fat Quarter 21" x 18"
# 3                      Flight of Feathers Painted  Fat Quarter 21" x 18"
# 4              Golden Girls Illustration in Peach  Fat Quarter 21" x 18"
# ..                                            ...                    ...
# 95  gold lips on graphite grey gray and gold kiss  Fat Quarter 21" x 18"
# 96   fall plaid || navy, rustic woods blue, white  Fat Quarter 21" x 18"
# 97                Leopard Rose Gold Spots on Pink  Fat Quarter 21" x 18"
# 98       A Galaxy Far Far Away - 1in chibi (gray)  Fat Quarter 21" x 18"
# 99                             Jurassic halloween  Fat Quarter 21" x 18"
#
#     price priceCurrency priceValidUntil
# 0   10.75           USD      2030-01-01
# 1   10.75           USD      2030-01-01
# 2   10.75           USD      2030-01-01
# 3   10.75           USD      2030-01-01
# 4   10.75           USD      2030-01-01
# ..    ...           ...             ...
# 95  10.75           USD      2030-01-01
# 96  10.75           USD      2030-01-01
# 97  10.75           USD      2030-01-01
# 98  10.75           USD      2030-01-01
# 99  10.75           USD      2030-01-01
#
# [100 rows x 8 columns]

# %%
products_df.shape
# Out:
# (222, 8)

# %%
# !python -m supercharged.main spoonflower --limit 10
# Out:
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50497
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50498
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50499
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50500
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50501
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50502
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50503
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50504
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50505
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 50506
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 2 took 16.521487712860107 seconds
# 5 took 16.70476484298706 seconds
# 1 took 16.920915842056274 seconds
# 3 took 17.013498783111572 seconds
# 4 took 17.14937686920166 seconds
# 6 took 17.267441749572754 seconds
# 7 took 17.37768793106079 seconds
# 8 took 17.46965193748474 seconds
# 9 took 17.6526939868927 seconds
# 0 took 17.828958988189697 seconds

# %%
# !python -m supercharged.main spoonflower --use_list_range --limit 5 --save_csv
# Out:
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 64731
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 64732
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 64733
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 64734
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 64735
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 2 took 14.258394002914429 seconds
# 0 took 14.740509986877441 seconds
# 3 took 15.081215858459473 seconds
# 4 took 15.445635080337524 seconds
# 1 took 16.433408975601196 seconds
