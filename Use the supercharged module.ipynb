# %%
from supercharged.storage import df_from_sql

# %%
tables = [
    'spoonflower_links',
    'spoonflower_fabrics'
]

# %%
links_df = df_from_sql(tables[0])
products_df = df_from_sql(tables[1])

# %%
links_df.head()
# Out:
#         id                                               slug  \
# 0  7522587      save-honey-bees-large-new-by-fernlesliestudio
# 1  1306112                         opal-by-peacoquettedesigns
# 2  9060289  saints-fleur-de-lis-new-orleans-saints-footbal...
# 3  5773745                  rainbow-pride-stripes-by-furbuddy
# 4  7812388                        dnd-pattern-by-neonborealis
#
#                                                 path  scraped
# 0  /en/fabric/7522587-save-honey-bees-large-new-b...        0
# 1      /en/fabric/1306112-opal-by-peacoquettedesigns        1
# 2  /en/fabric/9060289-saints-fleur-de-lis-new-orl...        0
# 3  /en/fabric/5773745-rainbow-pride-stripes-by-fu...        0
# 4     /en/fabric/7812388-dnd-pattern-by-neonborealis        0

# %%
links_df.shape
# Out:
# (84, 4)

# %%
products_df.head(n=100)
# Out:
#          id                                               slug  \
# 0   6444170                catching-fireflies-by-thestorysmith
# 1   3584004            mexican-sugar-skulls-small-by-lusykoror
# 2   7984669              8-love-care-medical-white-by-rebelmod
# 3   8619105               flight-feathers-painted-by-xoxotique
# 4   7944022  golden-girls-illustration-peach-by-yesterdayco...
# 5   5544045  napoleonic-bees-faux-gilt-on-blackest-black-by...
# 6   5939834                classic-leopard-by-cinneworthington
# 7   8618597      rainbow-watercolor-pawprints-by-dragonstarart
# 8   4893900          half-scale-m81-woodland-camo-by-ricraynor
# 9   5880084         mod-triangles-gold-indigo-by-crystal_walen
# 10  4534585                      super-words-dark-by-robyriker
# 11  5514018           hair-cutting-shears-by-cloudycapevintage
# 12  4995555  heart-health-awareness-light-gray-large-by-ohd...
# 13   991112                  nursing-coordinates-by-bluevelvet
# 14  9240316  irish-navy-green-shamrock-fabric-by-charlottew...
# 15  5839396                   spectacular-cats-by-cynthia_arre
# 16  1306112                         opal-by-peacoquettedesigns
# 17  8197261    night-sky-stars-midnight-blue-by-at_the_cottage
# 18  7790777                   turtles-aqua-blue-by-gingerlique
# 19  5033660                     80s-accessories-by-diannemehta
# 20  6327300   call-mountains-evergreen-med-by-nouveau_bohemian
# 21  2632362  colorful-happy-smiley-face-squares-large-print...
# 22  7236018  australian-native-eucalyptus-leaves-edition-1-...
# 23  4830872  cherry-blossom-watercolor-cherry-blossom-flora...
# 24  7580754   ibd-gracie-grace-golden-jumbo-by-indybloomdesign
# 25  7679631  scattered-earth-tones-watercolor-rainbows-by-a...
# 26  7463028  seamless-watercolor-larger-leaves-pattern-1-by...
# 27  6864327                     love-lips-red-by-hipkiddesigns
# 28  4981816            black-white-dogs-by-littleislandcompany
# 29  2623792     purple-space-stars-small-print-by-inspirationz
#
#                                                  path  \
# 0   /en/fabric/6444170-catching-fireflies-by-thest...
# 1   /en/fabric/3584004-mexican-sugar-skulls-small-...
# 2   /en/fabric/7984669-8-love-care-medical-white-b...
# 3   /en/fabric/8619105-flight-feathers-painted-by-...
# 4   /en/fabric/7944022-golden-girls-illustration-p...
# 5   /en/fabric/5544045-napoleonic-bees-faux-gilt-o...
# 6   /en/fabric/5939834-classic-leopard-by-cinnewor...
# 7   /en/fabric/8618597-rainbow-watercolor-pawprint...
# 8   /en/fabric/4893900-half-scale-m81-woodland-cam...
# 9   /en/fabric/5880084-mod-triangles-gold-indigo-b...
# 10   /en/fabric/4534585-super-words-dark-by-robyriker
# 11  /en/fabric/5514018-hair-cutting-shears-by-clou...
# 12  /en/fabric/4995555-heart-health-awareness-ligh...
# 13  /en/fabric/991112-nursing-coordinates-by-bluev...
# 14  /en/fabric/9240316-irish-navy-green-shamrock-f...
# 15  /en/fabric/5839396-spectacular-cats-by-cynthia...
# 16      /en/fabric/1306112-opal-by-peacoquettedesigns
# 17  /en/fabric/8197261-night-sky-stars-midnight-bl...
# 18  /en/fabric/7790777-turtles-aqua-blue-by-ginger...
# 19  /en/fabric/5033660-80s-accessories-by-diannemehta
# 20  /en/fabric/6327300-call-mountains-evergreen-me...
# 21  /en/fabric/2632362-colorful-happy-smiley-face-...
# 22  /en/fabric/7236018-australian-native-eucalyptu...
# 23  /en/fabric/4830872-cherry-blossom-watercolor-c...
# 24  /en/fabric/7580754-ibd-gracie-grace-golden-jum...
# 25  /en/fabric/7679631-scattered-earth-tones-water...
# 26  /en/fabric/7463028-seamless-watercolor-larger-...
# 27  /en/fabric/6864327-love-lips-red-by-hipkiddesigns
# 28  /en/fabric/4981816-black-white-dogs-by-littlei...
# 29  /en/fabric/2623792-purple-space-stars-small-pr...
#
#                                                 title                   size  \
# 0                                  Catching Fireflies  Fat Quarter 21" x 18"
# 1                        Mexican Sugar Skulls (small)  Fat Quarter 21" x 18"
# 2                     8" Love to Care Medical - White  Fat Quarter 21" x 18"
# 3                          Flight of Feathers Painted  Fat Quarter 21" x 18"
# 4                  Golden Girls Illustration in Peach  Fat Quarter 21" x 18"
# 5       Napoleonic Bees ~ Faux Gilt on Blackest Black  Fat Quarter 21" x 18"
# 6                                     classic leopard  Fat Quarter 21" x 18"
# 7                        Rainbow Watercolor Pawprints  Fat Quarter 21" x 18"
# 8                        Half Scale M81 Woodland Camo  Fat Quarter 21" x 18"
# 9                           Mod Triangles Gold Indigo  Fat Quarter 21" x 18"
# 10                                Super Words! (Dark)  Fat Quarter 21" x 18"
# 11                                Hair Cutting Shears  Fat Quarter 21" x 18"
# 12        Heart Health Awareness - Light Gray (large)  Fat Quarter 21" x 18"
# 13                                NURSING_COORDINATES  Fat Quarter 21" x 18"
# 14             irish - navy and green shamrock fabric  Fat Quarter 21" x 18"
# 15                                   Spectacular Cats  Fat Quarter 21" x 18"
# 16                                               Opal  Fat Quarter 21" x 18"
# 17                      Night Sky Stars Midnight Blue  Fat Quarter 21" x 18"
# 18                           Turtles in Aqua and Blue  Fat Quarter 21" x 18"
# 19                                    80s Accessories  Fat Quarter 21" x 18"
# 20              Call of the Mountains (evergreen) MED  Fat Quarter 21" x 18"
# 21   Colorful Happy Smiley face Squares (large print)  Fat Quarter 21" x 18"
# 22  Australian Native Eucalyptus Leaves || Edition...  Fat Quarter 21" x 18"
# 23  cherry blossom watercolor // cherry blossom fl...  Fat Quarter 21" x 18"
# 24                      IBD Gracie Grace Golden Jumbo  Fat Quarter 21" x 18"
# 25          Scattered Earth Tones Watercolor Rainbows  Fat Quarter 21" x 18"
# 26        SEAMLESS watercolor Larger leaves Pattern-1  Fat Quarter 21" x 18"
# 27                                   Love Lips // Red  Fat Quarter 21" x 18"
# 28                               Black and White Dogs  Fat Quarter 21" x 18"
# 29                   Purple Space Stars (small print)  Fat Quarter 21" x 18"
#
#     price priceCurrency priceValidUntil
# 0   10.75           USD      2030-01-01
# 1   10.75           USD      2030-01-01
# 2   10.75           USD      2030-01-01
# 3   10.75           USD      2030-01-01
# 4   10.75           USD      2030-01-01
# 5   10.75           USD      2030-01-01
# 6   10.75           USD      2030-01-01
# 7   10.75           USD      2030-01-01
# 8   10.75           USD      2030-01-01
# 9   10.75           USD      2030-01-01
# 10  10.75           USD      2030-01-01
# 11  10.75           USD      2030-01-01
# 12  10.75           USD      2030-01-01
# 13  10.75           USD      2030-01-01
# 14  10.75           USD      2030-01-01
# 15  10.75           USD      2030-01-01
# 16  10.75           USD      2030-01-01
# 17  10.75           USD      2030-01-01
# 18  10.75           USD      2030-01-01
# 19  10.75           USD      2030-01-01
# 20  10.75           USD      2030-01-01
# 21  10.75           USD      2030-01-01
# 22  10.75           USD      2030-01-01
# 23  10.75           USD      2030-01-01
# 24  10.75           USD      2030-01-01
# 25  10.75           USD      2030-01-01
# 26  10.75           USD      2030-01-01
# 27  10.75           USD      2030-01-01
# 28  10.75           USD      2030-01-01
# 29  10.75           USD      2030-01-01

# %%
# !python -m supercharged.main spoonflower --limit 10
# Out:
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57489
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57490
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57491
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57492
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57493
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57494
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57495
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57496
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57497
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# ChromeDriver was started successfully.
# Starting ChromeDriver 84.0.4147.30 (48b3e868b4cc0aa7e8149519690b6f6949e110a8-refs/branch-heads/4147@{#310}) on port 57498
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 1 took 16.45686101913452 seconds
# 5 took 16.784294843673706 seconds
# 4 took 17.031512022018433 seconds
# 2 took 17.17098903656006 seconds
# 8 took 17.284024000167847 seconds
# 6 took 17.418936014175415 seconds
# 7 took 17.583493947982788 seconds
# 0 took 18.003562927246094 seconds
# 9 took 18.72818899154663 seconds
# 3 took 19.58050513267517 seconds
# {"links": [], "product_data": {"id": "6327300", "slug": "call-mountains-evergreen-med-by-nouveau_bohemian", "path": "/en/fabric/6327300-call-mountains-evergreen-med-by-nouveau_bohemian", "title": "Call of the Mountains (evergreen) MED", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "2632362", "slug": "colorful-happy-smiley-face-squares-large-print-by-inspirationz", "path": "/en/fabric/2632362-colorful-happy-smiley-face-squares-large-print-by-inspirationz", "title": "Colorful Happy Smiley face Squares (large print)", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "7236018", "slug": "australian-native-eucalyptus-leaves-edition-1-australiana-fabric-wallpaper-by-erin__kendal", "path": "/en/fabric/7236018-australian-native-eucalyptus-leaves-edition-1-australiana-fabric-wallpaper-by-erin__kendal", "title": "Australian Native Eucalyptus Leaves || Edition 1 || Australiana Fabric Wallpaper", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "4830872", "slug": "cherry-blossom-watercolor-cherry-blossom-floral-by-magentarosedesigns", "path": "/en/fabric/4830872-cherry-blossom-watercolor-cherry-blossom-floral-by-magentarosedesigns", "title": "cherry blossom watercolor // cherry blossom floral", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "7580754", "slug": "ibd-gracie-grace-golden-jumbo-by-indybloomdesign", "path": "/en/fabric/7580754-ibd-gracie-grace-golden-jumbo-by-indybloomdesign", "title": "IBD Gracie Grace Golden Jumbo", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "7679631", "slug": "scattered-earth-tones-watercolor-rainbows-by-anniemontgomerydesign", "path": "/en/fabric/7679631-scattered-earth-tones-watercolor-rainbows-by-anniemontgomerydesign", "title": "Scattered Earth Tones Watercolor Rainbows", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "7463028", "slug": "seamless-watercolor-larger-leaves-pattern-1-by-daily_miracles", "path": "/en/fabric/7463028-seamless-watercolor-larger-leaves-pattern-1-by-daily_miracles", "title": "SEAMLESS watercolor Larger leaves Pattern-1", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "6864327", "slug": "love-lips-red-by-hipkiddesigns", "path": "/en/fabric/6864327-love-lips-red-by-hipkiddesigns", "title": "Love Lips // Red", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "4981816", "slug": "black-white-dogs-by-littleislandcompany", "path": "/en/fabric/4981816-black-white-dogs-by-littleislandcompany", "title": "Black and White Dogs", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}
# {"links": [], "product_data": {"id": "2623792", "slug": "purple-space-stars-small-print-by-inspirationz", "path": "/en/fabric/2623792-purple-space-stars-small-print-by-inspirationz", "title": "Purple Space Stars (small print)", "size": "Fat Quarter 21\" x 18\"", "price": "10.75", "priceCurrency": "USD", "priceValidUntil": "2030-01-01"}}

# %%
sub_links_df = links_df.copy()
sub_links_df = sub_links_df[sub_links_df['scraped'] == 0]
sub_links_df = sub_links_df.sample(10)
sub_links_df.head(n=10)
# Out:
#          id                                               slug  \
# 62  6812243       cute-kawaii-sushi-small-size-by-penguinhouse
# 33  3817098                            math-count-on-by-sammyk
# 42  7984669              8-love-care-medical-white-by-rebelmod
# 4   7812388                        dnd-pattern-by-neonborealis
# 70  7587085  heres-heart-navy-white-gold2-sketch-1-by-doodl...
# 55  4534585                      super-words-dark-by-robyriker
# 10  8692520  bees-lemons-large-blue-original-colors-by-fern...
# 82  6444170                catching-fireflies-by-thestorysmith
# 34  8039248  forest-animal-hot-air-balloon-night-adventure-...
# 12  2330040                         maryland-flags-by-elramsay
#
#                                                  path  scraped
# 62  /en/fabric/6812243-cute-kawaii-sushi-small-siz...        0
# 33         /en/fabric/3817098-math-count-on-by-sammyk        0
# 42  /en/fabric/7984669-8-love-care-medical-white-b...        0
# 4      /en/fabric/7812388-dnd-pattern-by-neonborealis        0
# 70  /en/fabric/7587085-heres-heart-navy-white-gold...        0
# 55   /en/fabric/4534585-super-words-dark-by-robyriker        0
# 10  /en/fabric/8692520-bees-lemons-large-blue-orig...        0
# 82  /en/fabric/6444170-catching-fireflies-by-thest...        0
# 34  /en/fabric/8039248-forest-animal-hot-air-ballo...        0
# 12      /en/fabric/2330040-maryland-flags-by-elramsay        0

# %%
urls = [f"https://www.spoonflower.com{x}" for x in sub_links_df.path.tolist()]
urls
# Out:
# ['https://www.spoonflower.com/en/fabric/6812243-cute-kawaii-sushi-small-size-by-penguinhouse',
#  'https://www.spoonflower.com/en/fabric/3817098-math-count-on-by-sammyk',
#  'https://www.spoonflower.com/en/fabric/7984669-8-love-care-medical-white-by-rebelmod',
#  'https://www.spoonflower.com/en/fabric/7812388-dnd-pattern-by-neonborealis',
#  'https://www.spoonflower.com/en/fabric/7587085-heres-heart-navy-white-gold2-sketch-1-by-doodleandcharm_',
#  'https://www.spoonflower.com/en/fabric/4534585-super-words-dark-by-robyriker',
#  'https://www.spoonflower.com/en/fabric/8692520-bees-lemons-large-blue-original-colors-by-fernlesliestudio',
#  'https://www.spoonflower.com/en/fabric/6444170-catching-fireflies-by-thestorysmith',
#  'https://www.spoonflower.com/en/fabric/8039248-forest-animal-hot-air-balloon-night-adventure-by-at_the_cottage',
#  'https://www.spoonflower.com/en/fabric/2330040-maryland-flags-by-elramsay']

# %%
scraped_ids = sub_links_df.id.tolist()
scraped_ids
# Out:
# ['6812243',
#  '3817098',
#  '7984669',
#  '7812388',
#  '7587085',
#  '4534585',
#  '8692520',
#  '6444170',
#  '8039248',
#  '2330040']

# %%
# links_df.loc[<cond>, 'cols'] = 1
link_cod = links_df['id'].isin(scraped_ids)
links_df.loc[link_cod, 'scraped'] = 1

# %%
links_df[links_df['scraped'] == 1].shape
# Out:
# (10, 4)
